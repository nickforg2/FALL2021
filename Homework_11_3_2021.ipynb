# %% [markdown]
# <a href="https://colab.research.google.com/github/nickforg2/FALL2021/blob/main/Homework_11_3_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns


df = pd.read_csv("https://raw.githubusercontent.com/nickforg2/FALL2021/main/drugs.csv")

df.head()
# Out:
#         State  ...  Rates.Tobacco.Use Past Month.26+
# 0     Alabama  ...                          0.330659
# 1      Alaska  ...                          0.304220
# 2     Arizona  ...                          0.309969
# 3    Arkansas  ...                          0.391210
# 4  California  ...                          0.220699
#
# [5 rows x 53 columns]

# %%
df.isnull().sum()
# Out:
# State                                                0
# Year                                                 0
# Population.12-17                                     0
# Population.18-25                                     0
# Population.26+                                       0
# Totals.Alcohol.Use Disorder Past Year.12-17          0
# Totals.Alcohol.Use Disorder Past Year.18-25          0
# Totals.Alcohol.Use Disorder Past Year.26+            0
# Rates.Alcohol.Use Disorder Past Year.12-17           0
# Rates.Alcohol.Use Disorder Past Year.18-25           0
# Rates.Alcohol.Use Disorder Past Year.26+             0
# Totals.Alcohol.Use Past Month.12-17                  0
# Totals.Alcohol.Use Past Month.18-25                  0
# Totals.Alcohol.Use Past Month.26+                    0
# Rates.Alcohol.Use Past Month.12-17                   0
# Rates.Alcohol.Use Past Month.18-25                   0
# Rates.Alcohol.Use Past Month.26+                     0
# ...

# %%
df.nunique()
# Out:
# State                                                 51
# Year                                                  17
# Population.12-17                                     866
# Population.18-25                                     867
# Population.26+                                       867
# Totals.Alcohol.Use Disorder Past Year.12-17           96
# Totals.Alcohol.Use Disorder Past Year.18-25          243
# Totals.Alcohol.Use Disorder Past Year.26+            398
# Rates.Alcohol.Use Disorder Past Year.12-17           860
# Rates.Alcohol.Use Disorder Past Year.18-25           866
# Rates.Alcohol.Use Disorder Past Year.26+             858
# Totals.Alcohol.Use Past Month.12-17                  209
# Totals.Alcohol.Use Past Month.18-25                  471
# Totals.Alcohol.Use Past Month.26+                    759
# Rates.Alcohol.Use Past Month.12-17                   863
# Rates.Alcohol.Use Past Month.18-25                   864
# ...

# %%
df.describe()
# Out:
#               Year  ...  Rates.Tobacco.Use Past Month.26+
# count   867.000000  ...                        867.000000
# mean   2010.000000  ...                          0.279927
# std       4.901807  ...                          0.047036
# min    2002.000000  ...                          0.149708
# 25%    2006.000000  ...                          0.250471
# 50%    2010.000000  ...                          0.279497
# 75%    2014.000000  ...                          0.311211
# max    2018.000000  ...                          0.409574
#
# [8 rows x 52 columns]

# %%
sns.catplot(data= df, kind ='box', height =10, aspect =1)

# %%
sns.catplot(x = 'State', data= df, kind ='count', height =10, aspect =1.5)

# %%
df.hist(figsize=(15,10), bins = 20, xlabelsize=10, ylabelsize=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0addaefd0>,
# ...
#       dtype=object)

# %%
import pandas as pd
import matplotlib.pyplot as plt

path_to_csv= "https://raw.githubusercontent.com/nickforg2/FALL2021/main/drugs.csv"
df= pd.read_csv(path_to_csv ,index_col=0)

plt.imshow(df,cmap='hot',interpolation='nearest')

plt.show()

# %%
import matplotlib.pyplot as plt 

x_coords =[2, 4, 6, 8, 10, 12, 14]
y_coords =[2.5,3, 6, 10, 13, 15, 16]
plt.plot(y_coords, x_coords)
plt.show()

# %% [markdown]
# ###1.) Define "Data Science" and explain the data science process
#    Data Science is the process of gaining insights from massive amounts of data using any methods that work. Companies generally don't mind the method in which one gains their insights as long as they are effective. The data science process involves collecting data, moving/storing data, exploring/transforming data, aggregating/labeling data, and eventually optimizing data. The video explains how depending on the size of the company, these tasks will be given to one or many people. Their jobs are to document, format, and inevitably complete the task at hand. If the company is smaller, they may have one person handling all data operations. However, if the company is larger, they can allocate more funds to hiring more specialized employees.
#
#
#
#
# ###2.) What is the difference between lists and tuples
# Lists are changeable but also take up more memory. This means that lists can be used to complete operations or edit data because they are editable. Tuples, on the other hand, are uneditable but they actually take up less memory. The major downside of tuples is the fact that the information cannot be changed so it is pretty irrelevant for a system that is dynamic. Unless if that system has certain entries that need to remain permanant.
#
# ###3.) Explain what the following major libraries do:
# <b>scikit learn- scikit learn provides a selection of tools used for machine learning.
#
# pandas- is a library that can help change data tables. Pandas is useful in design of certain machine learning projects.
#
# tensorflow- Used for fast numerical computing. Creates deeper learning modules.
#
# numpy- is used for working with arrays. Also, can assist in linear algebra and other mathmatics.
